# %%
#!pip install openai
#!pip install -U openai

# %%
import pandas as pd
users = pd.read_csv('coders-santander-2025.csv', sep=";").to_dict(orient='records')

for user in users:
    user['news'] = []

# %%
openai_api_key = "sk-proj-v2"

# %%
from openai import OpenAI

client = OpenAI(api_key=openai_api_key)

def generate_ai_news(user):
    completion = client.chat.completions.create(
        model="gpt-5.2",
        messages=[
            {
                "role": "system",
                "content": "Você é um apaixonado por produtos lacteos da Danone."
            },
            {
                "role": "user",
                "content": f"Crie uma mensagem para {user['name']} sobre o que cada produto Danone o torna único (máximo de 100 caracteres)"
            }
        ]
    )
    return completion.choices[0].message.content.strip('"')

for user in users:
    news = generate_ai_news(user)
    print(news)
    user['news'].append({
      "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/credit.svg",
      "description": news
  })
# Out:
# Danette: cremosidade irresistível; Activia: equilíbrio diário; YoPRO: alta proteína; Actimel: defesa.
# Cada Danone é único: sabor marcante, textura cremosa e nutrição que cuida de você.
# Danoninho: cada Danone é único—do cremoso ao nutritivo, sempre com sabor que marca!
# YoPro: proteína alta, zero lactose e sabor incrível—cada Danone é único no seu momento.
# Activia: fermentos exclusivos e sabor leve; cada Danone é único em textura e cremosidade.
# Activia: fibras e probióticos para seu intestino. Danone: cremosidade clássica todo dia.
